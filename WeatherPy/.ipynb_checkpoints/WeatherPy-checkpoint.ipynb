# %% [markdown]
# # WeatherPy

# %%
import sys
sys.path.append("..")

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
WeatherPy = pd.read_csv('output_data/cities.csv',index_col='City')
WeatherPy.reset_index(inplace=True)

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
WeatherPy
# Out:
#             City  City_ID  Cloudiness Country        Date  Humidity    Lat  \
# 0      ostrovnoy        0           2      RU  1558378754        72  68.05
# 1      mahebourg        1          75      MU  1558378503        74 -20.41
# 2        qaanaaq        2          25      GL  1558378755        73  77.48
# 3         zhuhai        3           0      CN  1558378755        39  40.71
# 4      cape town        4          20      ZA  1558378755        76 -33.93
# ..           ...      ...         ...     ...         ...       ...    ...
# 543       yabrud      543           0      SY  1558378840        32  33.97
# 544      paraiso      544           5      MX  1558378898         4  24.01
# 545      veraval      545           0      FR  1558378898        62  49.65
# 546  novyy urgal      546         100      RU  1558378899        93  51.07
# 547      tongren      547           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# 0     39.51     37.50        7.16
# 1     57.70     78.80       11.41
# 2    -69.36     22.20        2.37
# 3    112.04     44.60        4.47
# 4     18.42     55.99        8.05
# ..      ...       ...         ...
# 543   36.66     80.60        8.05
# 544 -104.61     84.20       16.11
# 545    0.71     61.00        8.05
# 546  132.56     49.74        2.68
# 547  109.18     55.86        2.84
#
# [548 rows x 10 columns]

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls

# %%
import pprint

# %%
print.print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5088\3358730996.py in <module>
# ----> 1 print.print()
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'print'

# %%
url = "https://api.openweathermap.org/data/2.5/weather"

# use iterrows to iterate through pandas dataframe
for index, row in WeatherPy.iterrows():
    
    params = {
    "appid": weather_api_key,
}

    # get city name from df
    city_name = row['City']

    # add keyword to params dict
    params['q'] = city_name

    # assemble url and make API request
    response = requests.get(url, params=params).json()
    
    #pprint.pprint(response)
    
    try:
        print(f"Processing Record {index} | {city_name}")
        
        # extract results
        results = response["name"]
     
    except (KeyError, IndexError):
        print("City not found... skipping.")
# Out:
# Processing Record 0 | ostrovnoy
# Processing Record 1 | mahebourg
# Processing Record 2 | qaanaaq
# Processing Record 3 | zhuhai
# Processing Record 4 | cape town
# Processing Record 5 | atuona
# Processing Record 6 | flinders
# Processing Record 7 | opuwo
# Processing Record 8 | tiksi
# Processing Record 9 | pushkinskiye gory
# Processing Record 10 | aykhal
# Processing Record 11 | castro
# Processing Record 12 | avarua
# Processing Record 13 | saskylakh
# Processing Record 14 | constitucion
# Processing Record 15 | albany
# Processing Record 16 | vilyuysk
# Processing Record 17 | ushuaia
# Processing Record 18 | bambous virieux
# Processing Record 19 | kodinsk
# Processing Record 20 | teknaf
# Processing Record 21 | busselton
# Processing Record 22 | ambon
# Processing Record 23 | maragogi
# Processing Record 24 | fallon
# Processing Record 25 | kantang
# Processing Record 26 | colonelganj
# Processing Record 27 | punta arenas
# Processing Record 28 | rikitea
# Processing Record 29 | new norfolk
# Processing Record 30 | gobabis
# Processing Record 31 | qingdao
# Processing Record 32 | port hardy
# Processing Record 33 | arman
# Processing Record 34 | mamakan
# Processing Record 35 | bethel
# Processing Record 36 | clinton
# Processing Record 37 | varhaug
# Processing Record 38 | ayan
# Processing Record 39 | mayor pablo lagerenza
# Processing Record 40 | hermanus
# Processing Record 41 | torbay
# Processing Record 42 | yellowknife
# Processing Record 43 | kruisfontein
# Processing Record 44 | puerto ayora
# Processing Record 45 | rosita
# Processing Record 46 | beloha
# Processing Record 47 | port elizabeth
# Processing Record 48 | port alfred
# Processing Record 49 | garchitorena
# Processing Record 50 | kodiak
# Processing Record 51 | mar del plata
# Processing Record 52 | taybad
# Processing Record 53 | cabo san lucas
# Processing Record 54 | tiarei
# Processing Record 55 | khatanga
# Processing Record 56 | pisco
# Processing Record 57 | kolyvan
# Processing Record 58 | hofn
# Processing Record 59 | bontang
# Processing Record 60 | sault sainte marie
# Processing Record 61 | zhigansk
# Processing Record 62 | thompson
# Processing Record 63 | pevek
# Processing Record 64 | nanortalik
# Processing Record 65 | bilibino
# Processing Record 66 | dikson
# Processing Record 67 | hambantota
# Processing Record 68 | beja
# Processing Record 69 | fortuna
# Processing Record 70 | ponta do sol
# Processing Record 71 | qasigiannguit
# Processing Record 72 | butaritari
# Processing Record 73 | virginia beach
# Processing Record 74 | hobyo
# Processing Record 75 | saint george
# Processing Record 76 | pontes e lacerda
# Processing Record 77 | khor
# Processing Record 78 | crotone
# Processing Record 79 | baglung
# Processing Record 80 | raglan
# Processing Record 81 | jamestown
# Processing Record 82 | sur
# Processing Record 83 | araouane
# Processing Record 84 | emerald
# Processing Record 85 | launceston
# Processing Record 86 | nikolskoye
# Processing Record 87 | ambilobe
# Processing Record 88 | cidreira
# Processing Record 89 | ternate
# Processing Record 90 | tarauaca
# Processing Record 91 | bella vista
# Processing Record 92 | xichang
# Processing Record 93 | antioch
# Processing Record 94 | najran
# Processing Record 95 | agirish
# Processing Record 96 | mataura
# Processing Record 97 | katsuura
# Processing Record 98 | shalinskoye
# Processing Record 99 | barrow
# Processing Record 100 | sorong
# Processing Record 101 | kingston
# Processing Record 102 | ketchikan
# Processing Record 103 | kapaa
# Processing Record 104 | mbigou
# Processing Record 105 | yakeshi
# Processing Record 106 | hilo
# Processing Record 107 | whitehorse
# Processing Record 108 | bonthe
# Processing Record 109 | bara
# Processing Record 110 | lompoc
# Processing Record 111 | port blair
# Processing Record 112 | bredasdorp
# Processing Record 113 | thinadhoo
# Processing Record 114 | koumac
# Processing Record 115 | faanui
# Processing Record 116 | xam nua
# Processing Record 117 | east london
# Processing Record 118 | sao filipe
# Processing Record 119 | deputatskiy
# Processing Record 120 | chuy
# Processing Record 121 | sitka
# Processing Record 122 | forio
# Processing Record 123 | russkaya polyana
# Processing Record 124 | san felipe
# Processing Record 125 | arraial do cabo
# Processing Record 126 | margate
# Processing Record 127 | aklavik
# Processing Record 128 | lokosovo
# Processing Record 129 | paita
# Processing Record 130 | cravo norte
# Processing Record 131 | motygino
# Processing Record 132 | west wendover
# Processing Record 133 | adrar
# Processing Record 134 | melfi
# Processing Record 135 | kibaya
# Processing Record 136 | iqaluit
# Processing Record 137 | lavrentiya
# Processing Record 138 | morondava
# Processing Record 139 | vaini
# Processing Record 140 | georgetown
# Processing Record 141 | sanchazi
# Processing Record 142 | sarai mir
# Processing Record 143 | yichun
# Processing Record 144 | plainview
# Processing Record 145 | comodoro rivadavia
# Processing Record 146 | nardaran
# Processing Record 147 | nagua
# Processing Record 148 | ibra
# Processing Record 149 | ganzhou
# Processing Record 150 | talnakh
# Processing Record 151 | coahuayana
# Processing Record 152 | sinnamary
# Processing Record 153 | porto novo
# Processing Record 154 | havoysund
# Processing Record 155 | bjornevatn
# Processing Record 156 | narsaq
# Processing Record 157 | charlestown
# Processing Record 158 | trat
# Processing Record 159 | manado
# Processing Record 160 | trapani
# Processing Record 161 | sao joao da barra
# Processing Record 162 | saint-philippe
# Processing Record 163 | haines junction
# Processing Record 164 | kathmandu
# Processing Record 165 | norman wells
# Processing Record 166 | brainerd
# Processing Record 167 | yumen
# Processing Record 168 | straumen
# Processing Record 169 | camacha
# Processing Record 170 | teya
# Processing Record 171 | vitim
# Processing Record 172 | antsohihy
# Processing Record 173 | kavieng
# Processing Record 174 | la esperanza
# Processing Record 175 | clyde river
# Processing Record 176 | nador
# Processing Record 177 | keflavik
# Processing Record 178 | faya
# Processing Record 179 | chokurdakh
# Processing Record 180 | le marin
# Processing Record 181 | tasiilaq
# Processing Record 182 | udachnyy
# Processing Record 183 | monrovia
# Processing Record 184 | burnie
# Processing Record 185 | kaitangata
# Processing Record 186 | yamada
# Processing Record 187 | mackay
# Processing Record 188 | lagoa
# Processing Record 189 | bluff
# Processing Record 190 | saint-georges
# Processing Record 191 | naryan-mar
# Processing Record 192 | port hedland
# Processing Record 193 | hithadhoo
# Processing Record 194 | beringovskiy
# Processing Record 195 | codrington
# Processing Record 196 | ilulissat
# Processing Record 197 | coquimbo
# Processing Record 198 | grand baie
# Processing Record 199 | kaabong
# Processing Record 200 | lazaro cardenas
# Processing Record 201 | luanda
# Processing Record 202 | rio gallegos
# Processing Record 203 | namatanai
# Processing Record 204 | severo-kurilsk
# Processing Record 205 | hutang
# Processing Record 206 | namioka
# Processing Record 207 | mnogovershinnyy
# Processing Record 208 | san rafael del sur
# Processing Record 209 | paamiut
# Processing Record 210 | ribeira grande
# Processing Record 211 | labuhan
# Processing Record 212 | mount gambier
# Processing Record 213 | pesca
# Processing Record 214 | mount isa
# Processing Record 215 | le port
# Processing Record 216 | hobart
# Processing Record 217 | dublin
# Processing Record 218 | salalah
# Processing Record 219 | beisfjord
# Processing Record 220 | ust-tsilma
# Processing Record 221 | marawi
# Processing Record 222 | samana
# Processing Record 223 | koronowo
# Processing Record 224 | ekimchan
# Processing Record 225 | carnarvon
# Processing Record 226 | saint-denis
# Processing Record 227 | tabas
# Processing Record 228 | san pedro
# Processing Record 229 | aketi
# Processing Record 230 | moses lake
# Processing Record 231 | mocuba
# Processing Record 232 | hamilton
# Processing Record 233 | san juan del sur
# Processing Record 234 | katobu
# Processing Record 235 | banjar
# Processing Record 236 | provideniya
# Processing Record 237 | andradas
# Processing Record 238 | bose
# Processing Record 239 | manzhouli
# Processing Record 240 | lockhart
# Processing Record 241 | anadyr
# Processing Record 242 | bandarbeyla
# Processing Record 243 | buchach
# Processing Record 244 | pasni
# Processing Record 245 | tuktoyaktuk
# Processing Record 246 | okha
# Processing Record 247 | puerto escondido
# Processing Record 248 | ancud
# Processing Record 249 | lebu
# Processing Record 250 | port lincoln
# Processing Record 251 | leningradskiy
# Processing Record 252 | kajaani
# Processing Record 253 | murray bridge
# Processing Record 254 | rocha
# Processing Record 255 | tagusao
# Processing Record 256 | cobija
# Processing Record 257 | port-gentil
# Processing Record 258 | te anau
# Processing Record 259 | hami
# Processing Record 260 | pahrump
# Processing Record 261 | fort frances
# Processing Record 262 | umtata
# Processing Record 263 | markova
# Processing Record 264 | saint-leu
# Processing Record 265 | jalu
# Processing Record 266 | alice springs
# Processing Record 267 | zaraza
# Processing Record 268 | dingle
# Processing Record 269 | bodden town
# Processing Record 270 | griffith
# Processing Record 271 | coihaique
# Processing Record 272 | sao felix do xingu
# Processing Record 273 | santa rosa
# Processing Record 274 | goderich
# Processing Record 275 | vila velha
# Processing Record 276 | rabo de peixe
# Processing Record 277 | soyo
# Processing Record 278 | cayenne
# Processing Record 279 | saldanha
# Processing Record 280 | santa ines
# Processing Record 281 | hasaki
# Processing Record 282 | slave lake
# Processing Record 283 | christchurch
# Processing Record 284 | kibakwe
# Processing Record 285 | luderitz
# Processing Record 286 | san andres
# Processing Record 287 | pangnirtung
# Processing Record 288 | san quintin
# Processing Record 289 | union
# Processing Record 290 | dudinka
# Processing Record 291 | florida
# Processing Record 292 | madikeri
# Processing Record 293 | esperance
# Processing Record 294 | takoradi
# Processing Record 295 | lokomotivnyy
# Processing Record 296 | khash
# Processing Record 297 | mogok
# Processing Record 298 | mikkeli
# Processing Record 299 | jiuquan
# Processing Record 300 | betafo
# Processing Record 301 | aitape
# Processing Record 302 | alofi
# Processing Record 303 | yulara
# Processing Record 304 | kvarkeno
# Processing Record 305 | salinopolis
# Processing Record 306 | chunhuhub
# Processing Record 307 | dunedin
# Processing Record 308 | nioro
# Processing Record 309 | upernavik
# Processing Record 310 | airai
# Processing Record 311 | balkanabat
# Processing Record 312 | syumsi
# Processing Record 313 | loukhi
# Processing Record 314 | baruun-urt
# Processing Record 315 | miraflores
# Processing Record 316 | gunjur
# Processing Record 317 | wajima
# Processing Record 318 | buala
# Processing Record 319 | acari
# Processing Record 320 | banfora
# Processing Record 321 | mandera
# Processing Record 322 | tshikapa
# Processing Record 323 | juneau
# Processing Record 324 | sidney
# Processing Record 325 | edd
# Processing Record 326 | cockburn town
# Processing Record 327 | kizukuri
# Processing Record 328 | vung tau
# Processing Record 329 | mahon
# Processing Record 330 | biltine
# Processing Record 331 | ishigaki
# Processing Record 332 | morant bay
# Processing Record 333 | raduzhnyy
# Processing Record 334 | san patricio
# Processing Record 335 | hulan ergi
# Processing Record 336 | thayetmyo
# Processing Record 337 | acapulco
# Processing Record 338 | port shepstone
# Processing Record 339 | tautira
# Processing Record 340 | la libertad
# Processing Record 341 | raymond
# Processing Record 342 | road town
# Processing Record 343 | yar-sale
# Processing Record 344 | iwanai
# Processing Record 345 | eseka
# Processing Record 346 | chiredzi
# Processing Record 347 | tigil
# Processing Record 348 | avera
# Processing Record 349 | muzhi
# Processing Record 350 | komsomolskiy
# Processing Record 351 | chapais
# Processing Record 352 | biak
# Processing Record 353 | darhan
# Processing Record 354 | daru
# Processing Record 355 | onokhoy
# Processing Record 356 | leh
# Processing Record 357 | banda aceh
# Processing Record 358 | alyangula
# Processing Record 359 | sorland
# Processing Record 360 | fort nelson
# Processing Record 361 | boyolangu
# Processing Record 362 | datong
# Processing Record 363 | vila franca do campo
# Processing Record 364 | akureyri
# Processing Record 365 | ulladulla
# Processing Record 366 | ust-barguzin
# Processing Record 367 | pampierstad
# Processing Record 368 | zyryanovsk
# Processing Record 369 | cooma
# Processing Record 370 | sfantu gheorghe
# Processing Record 371 | carballo
# Processing Record 372 | shimoda
# Processing Record 373 | novonukutskiy
# Processing Record 374 | reguengos de monsaraz
# Processing Record 375 | ocean city
# Processing Record 376 | qinhuangdao
# Processing Record 377 | muskegon
# Processing Record 378 | kargasok
# Processing Record 379 | auki
# Processing Record 380 | kayseri
# Processing Record 381 | quanzhou
# Processing Record 382 | nago
# Processing Record 383 | medicine hat
# Processing Record 384 | cherskiy
# Processing Record 385 | santa maria
# Processing Record 386 | north bend
# Processing Record 387 | el alto
# Processing Record 388 | geraldton
# Processing Record 389 | souillac
# Processing Record 390 | la ronge
# Processing Record 391 | namibe
# Processing Record 392 | westport
# Processing Record 393 | juiz de fora
# Processing Record 394 | lagos
# Processing Record 395 | half moon bay
# Processing Record 396 | nelson bay
# Processing Record 397 | tuatapere
# Processing Record 398 | grindavik
# Processing Record 399 | xining
# Processing Record 400 | kieta
# Processing Record 401 | kalabo
# Processing Record 402 | sambava
# Processing Record 403 | wawa
# Processing Record 404 | manama
# Processing Record 405 | labuan
# Processing Record 406 | wexford
# Processing Record 407 | kyren
# Processing Record 408 | boquira
# Processing Record 409 | bathsheba
# Processing Record 410 | ogbomosho
# Processing Record 411 | longyearbyen
# Processing Record 412 | diu
# Processing Record 413 | shebalino
# Processing Record 414 | kalat
# Processing Record 415 | hare bay
# Processing Record 416 | kirkuk
# Processing Record 417 | tabou
# Processing Record 418 | ahipara
# Processing Record 419 | byron bay
# Processing Record 420 | isangel
# Processing Record 421 | saint-joseph
# Processing Record 422 | susuman
# Processing Record 423 | plattling
# Processing Record 424 | arenapolis
# Processing Record 425 | tocopilla
# Processing Record 426 | arroyo
# Processing Record 427 | hastings
# Processing Record 428 | okhotsk
# Processing Record 429 | maniitsoq
# Processing Record 430 | meulaboh
# Processing Record 431 | cartagena del chaira
# Processing Record 432 | macau
# Processing Record 433 | svodin
# Processing Record 434 | victoria
# Processing Record 435 | dong xoai
# Processing Record 436 | zaysan
# Processing Record 437 | sioux lookout
# Processing Record 438 | waipawa
# Processing Record 439 | vila do maio
# Processing Record 440 | brae
# Processing Record 441 | russkiy aktash
# Processing Record 442 | kokstad
# Processing Record 443 | lucapa
# Processing Record 444 | birjand
# Processing Record 445 | ingham
# Processing Record 446 | henties bay
# Processing Record 447 | tilichiki
# Processing Record 448 | doha
# Processing Record 449 | makakilo city
# Processing Record 450 | lorengau
# Processing Record 451 | anan
# Processing Record 452 | synya
# Processing Record 453 | thanatpin
# Processing Record 454 | altagracia de orituco
# Processing Record 455 | anqing
# Processing Record 456 | nome
# Processing Record 457 | lahaina
# Processing Record 458 | hereford
# Processing Record 459 | san ramon de la nueva oran
# Processing Record 460 | manuk mangkaw
# Processing Record 461 | prainha
# Processing Record 462 | pacific grove
# Processing Record 463 | tam ky
# Processing Record 464 | atasu
# Processing Record 465 | seshcha
# Processing Record 466 | norilsk
# Processing Record 467 | los teques
# Processing Record 468 | san cristobal
# Processing Record 469 | san ramon
# Processing Record 470 | horta
# Processing Record 471 | poum
# Processing Record 472 | sawtell
# Processing Record 473 | seoul
# Processing Record 474 | plettenberg bay
# Processing Record 475 | oranjestad
# Processing Record 476 | belmonte
# Processing Record 477 | bundaberg
# Processing Record 478 | samarinda
# Processing Record 479 | zhezkazgan
# Processing Record 480 | abonnema
# Processing Record 481 | narok
# Processing Record 482 | muravlenko
# Processing Record 483 | necochea
# Processing Record 484 | talcahuano
# Processing Record 485 | san-pedro
# Processing Record 486 | bismarck
# Processing Record 487 | pinotepa de don luis
# Processing Record 488 | mizan teferi
# Processing Record 489 | bonfim
# Processing Record 490 | oga
# Processing Record 491 | bouca
# Processing Record 492 | bolobo
# Processing Record 493 | nuuk
# Processing Record 494 | baylo
# Processing Record 495 | fuxin
# Processing Record 496 | chernaya kholunitsa
# Processing Record 497 | havelock
# Processing Record 498 | traverse city
# Processing Record 499 | champoton
# Processing Record 500 | mandalgovi
# Processing Record 501 | delemont
# Processing Record 502 | chauk
# Processing Record 503 | kambove
# Processing Record 504 | tutoia
# Processing Record 505 | touros
# Processing Record 506 | babati
# Processing Record 507 | graaff-reinet
# Processing Record 508 | noumea
# Processing Record 509 | pilot butte
# Processing Record 510 | atar
# Processing Record 511 | valenca do piaui
# Processing Record 512 | natchez
# Processing Record 513 | denpasar
# Processing Record 514 | loikaw
# Processing Record 515 | madaoua
# Processing Record 516 | malindi
# Processing Record 517 | along
# Processing Record 518 | bonito
# Processing Record 519 | saint anthony
# Processing Record 520 | high prairie
# Processing Record 521 | high rock
# Processing Record 522 | raudeberg
# Processing Record 523 | kununurra
# Processing Record 524 | mogadishu
# Processing Record 525 | mecca
# Processing Record 526 | viedma
# Processing Record 527 | tomatlan
# Processing Record 528 | lyuban
# Processing Record 529 | bonavista
# Processing Record 530 | hirara
# Processing Record 531 | russell
# Processing Record 532 | burns lake
# Processing Record 533 | hakkari
# Processing Record 534 | marzuq
# Processing Record 535 | villaviciosa
# Processing Record 536 | padang
# Processing Record 537 | matam
# Processing Record 538 | la seyne-sur-mer
# Processing Record 539 | palu
# Processing Record 540 | talmenka
# Processing Record 541 | tamworth
# Processing Record 542 | perth
# Processing Record 543 | yabrud
# Processing Record 544 | paraiso
# Processing Record 545 | veraval
# Processing Record 546 | novyy urgal
# Processing Record 547 | tongren

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
city_data = WeatherPy.loc[:,["City","Lat","Lng","Max Temp","Humidity", "Cloudiness","Wind Speed","Country", "Date"]].head()
city_data["Lat"] = city_data["Lat"].map("{:,.2f}".format)
city_data["Lng"] = city_data["Lng"].map("{:,.2f}".format)
city_data["Max Temp"] = city_data["Max Temp"].map("{:,.2f}".format)
city_data["Wind Speed"] = city_data["Wind Speed"].map("{:,.2f}".format)
city_data
# Out:
#         City     Lat     Lng Max Temp  Humidity  Cloudiness Wind Speed  \
# 0  ostrovnoy   68.05   39.51    37.50        72           2       7.16
# 1  mahebourg  -20.41   57.70    78.80        74          75      11.41
# 2    qaanaaq   77.48  -69.36    22.20        73          25       2.37
# 3     zhuhai   40.71  112.04    44.60        39           0       4.47
# 4  cape town  -33.93   18.42    55.99        76          20       8.05
#
#   Country        Date
# 0      RU  1558378754
# 1      MU  1558378503
# 2      GL  1558378755
# 3      CN  1558378755
# 4      ZA  1558378755

# %%
print(city_data.describe(include='all'))
# Out:
#              City    Lat    Lng Max Temp   Humidity  Cloudiness Wind Speed  \
# count           5      5      5        5   5.000000     5.00000          5
# unique          5      5      5        5        NaN         NaN          5
# top     mahebourg  77.48  39.51    37.50        NaN         NaN       2.37
# freq            1      1      1        1        NaN         NaN          1
# mean          NaN    NaN    NaN      NaN  66.800000    24.40000        NaN
# std           NaN    NaN    NaN      NaN  15.610894    30.31996        NaN
# min           NaN    NaN    NaN      NaN  39.000000     0.00000        NaN
# 25%           NaN    NaN    NaN      NaN  72.000000     2.00000        NaN
# 50%           NaN    NaN    NaN      NaN  73.000000    20.00000        NaN
# 75%           NaN    NaN    NaN      NaN  74.000000    25.00000        NaN
# max           NaN    NaN    NaN      NaN  76.000000    75.00000        NaN
#
#        Country          Date
# count        5  5.000000e+00
# unique       5           NaN
# top         CN           NaN
# freq         1           NaN
# mean       NaN  1.558379e+09
# std        NaN  1.125869e+02
# min        NaN  1.558379e+09
# 25%        NaN  1.558379e+09
# 50%        NaN  1.558379e+09
# 75%        NaN  1.558379e+09
# max        NaN  1.558379e+09

# %% [markdown]
# ### Inspect the data and remove the cities where the humidity > 100%.

# %%
high_humidity= city_data.loc[city_data["Humidity"]>100]
high_humidity
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
city_data.plot(kind="scatter", x="Lat", y="Max Temperature (F)", grid=True, figsize=(8,8),
              title="City Latitude vs. Max Temperature (04/01/20)", facecolors="blue", edgecolors="black")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Max Temperature (F)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5088\3125034048.py in <module>
#       1 city_data.plot(kind="scatter", x="Lat", y="Max Temperature (F)", grid=True, figsize=(8,8),
# ----> 2               title="City Latitude vs. Max Temperature (04/01/20)", facecolors="blue", edgecolors="black")
#       3 plt.show()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     790         if kind in self._dataframe_kinds:
#     791             if isinstance(data, ABCDataFrame):
# --> 792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
#     794                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#     969         scatter = ax.scatter(
#     970             data[x].values,
# --> 971             data[y].values,
#     972             c=c_values,
#     973             label=label,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Max Temperature (F)'

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
#x_limit = 100
#x_axis = np.arange(0, x_limit, 100)

city_data.plot(kind="scatter", x="Lat", y="Humidity %", grid=True, figsize=(8,8),
              title="City Latitude vs. Humidity (04/01/20)", facecolors="blue", edgecolors="black")
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data.iloc[:,1],wdi_data.iloc[:,8])
plt.title('City Latitude vs. Cloud Speed (04/01/20)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data.iloc[:,1],wdi_data.iloc[:,8])
plt.title('City Latitude vs. Wind Speed (04/01/20)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()
